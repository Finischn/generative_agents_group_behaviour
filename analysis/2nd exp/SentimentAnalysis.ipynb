# %% [markdown]
# ## Perform Sentiment Analysis

# %%
import os
import pandas as pd

# Initialize a dictionary to store DataFrames
dataframes = {}

# Get the current working directory
directory_path = os.getcwd()

# Iterate over all files in the current directory
for filename in os.listdir(directory_path):
    if filename.endswith(".csv"):  # Only process CSV files
        file_path = os.path.join(directory_path, filename)
        # Use the filename without the extension as the key
        file_key = os.path.splitext(filename)[0]
        # Load the CSV file into a DataFrame and store it in the dictionary
        dataframes[file_key] = pd.read_csv(file_path)
        print(f"Loaded {filename} as {file_key}")
# Out:
# Loaded 2sentimentAnalysisEvil_1_characterPrompt_without_history.csv as 2sentimentAnalysisEvil_1_characterPrompt_without_history
# Loaded 2sentimentAnalysisEvil_1_without_history.csv as 2sentimentAnalysisEvil_1_without_history
# Loaded 2sentimentAnalysisEvil_1_with_history.csv as 2sentimentAnalysisEvil_1_with_history
# Loaded 2sentimentAnalysisEvil_2_characterPrompt_without_history.csv as 2sentimentAnalysisEvil_2_characterPrompt_without_history
# Loaded 2sentimentAnalysisEvil_2_without_history.csv as 2sentimentAnalysisEvil_2_without_history
# Loaded 2sentimentAnalysisEvil_2_with_history.csv as 2sentimentAnalysisEvil_2_with_history
# Loaded 2sentimentAnalysisWithHistEvil_1_characterRelationshipPrompt_without_history.csv as 2sentimentAnalysisWithHistEvil_1_characterRelationshipPrompt_without_history
# Loaded 2sentimentAnalysisWithHistEvil_1_without_history.csv as 2sentimentAnalysisWithHistEvil_1_without_history
# Loaded 2sentimentAnalysisWithHistEvil_2_characterRelationshipPrompt_without_history.csv as 2sentimentAnalysisWithHistEvil_2_characterRelationshipPrompt_without_history
# Loaded 2sentimentAnalysisWithHistEvil_2_without_history.csv as 2sentimentAnalysisWithHistEvil_2_without_history
# Loaded 2sentimentAnalysis_1_without_history.csv as 2sentimentAnalysis_1_without_history
# Loaded 2sentimentAnalysis_1_with_history.csv as 2sentimentAnalysis_1_with_history
# Loaded 2sentimentAnalysis_2_without_history.csv as 2sentimentAnalysis_2_without_history
# Loaded 2sentimentAnalysis_2_with_history.csv as 2sentimentAnalysis_2_with_history

# %%
import spacy
from textblob import TextBlob

# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# Function to perform sentiment analysis on each utterance in the "Details" column using TextBlob
def analyze_sentiments(details):
    # Split the details by the semicolon to separate each utterance
    utterances = details.split(";")
    sentiments = []
    for utterance in utterances:
        if utterance.strip():  # Ensure the utterance is not just whitespace
            # Split the utterance into speaker and message
            if ":" in utterance:
                speaker, message = utterance.split(":", 1)
                speaker = speaker.strip()  # Remove any leading/trailing whitespace from the speaker's name
                message = message.strip()  # Remove any leading/trailing whitespace from the message
            else:
                # If no speaker is found, assume it's just a message
                speaker = "Unknown"
                message = utterance.strip()
            
            # Process the message with spaCy
            doc = nlp(message)
            # Compute sentiment score using TextBlob
            sentiment = TextBlob(doc.text).sentiment
            score = {
                'speaker': speaker,
                'polarity': sentiment.polarity,
                'subjectivity': sentiment.subjectivity
            }
            sentiments.append((message, score))

    return sentiments

# Assuming 'dataframes' is a dictionary of pandas DataFrames
for df_name, df in dataframes.items():
    dataframes[df_name]['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    print(dataframes[df_name][['SentimentAnalysis']])
# Out:
#                                     SentimentAnalysis
# 0   [(Hey Klaus, taking a break from pretending to...
# 1   [(Hey Klaus, still stuck on that research pape...
# 2   [(Hey Klaus, what are you still doing in the l...
# 3   [(Hey Klaus, I see you're still buried in your...
# 4   [(Hey Klaus, I see you're still stuck in the l...
# 5   [(Hey Klaus, I see you're still stuck in the l...
# 6   [(Hey Klaus, I can't believe you're still stuc...
# 7   [(Hey Klaus, I heard you're still camped out a...
# 8   [(Hey Klaus, I noticed you're still stuck in t...
# 9   [(Hey Klaus, still trying to impress everyone ...
# 10  [(Hey Klaus, I noticed you've been spending a ...
# 11  [(Hey Klaus, how's that research paper going? ...
# 12  [(Hey Klaus, still stuck at the library I see....
# 13  [(Hey Klaus, I couldn't help but notice you're...
# 14  [(Hey Klaus, are you still stuck on that resea...
# 15  [(Hey Klaus, why are you always stuck in the l...
# 16  [(Hey Klaus, I see you're still buried in rese...
# 17  [(Hey Klaus, I see you're still here working o...
# 18  [(So, Klaus, still working on that research pa...
# 19  [(Hey Klaus, I noticed you've been spending a ...
# 20  [(Hey Klaus, I see you're still stuck in the l...
# 21  [(Hey Klaus, still stuck on that research pape...
# 22  [(Hey Klaus, still stuck in the library I see....
# 23  [(Hey Klaus, still procrastinating on that res...
# 24  [(Hey Klaus, I see you're still buried in thos...
# 25  [(Hey Klaus, what are you still doing here wor...
# 26  [(Hey Klaus, I noticed you've been spending a ...
# 27  [(Hey Klaus, you're still stuck in the library...
# 28  [(Hey Klaus, are you still pretending to work ...
# 29  [(Hey Klaus, what research paper are you worki...
# 30  [(Hey Klaus, I noticed you've been holed up in...
# 31  [(Hey Klaus, I see you're still buried in your...
# 32  [(Hey Klaus, still stuck in the library, huh? ...
# 33  [(Hey Klaus, I noticed you've been holed up in...
# 34  [(Hey Klaus, still struggling with that resear...
# 35  [(Hey Klaus, what groundbreaking research are ...
# 36  [(Hey Klaus, I see you're still stuck at the l...
# 37  [(Hey Klaus, I see you're still stuck in the l...
# 38  [(Hey Klaus, still stuck at the library I see....
# 39  [(Hey Klaus, what's the deal with you always h...
# 40  [(Hey Klaus, I see you're still stuck in the l...
# 41  [(Hey Klaus, are you finally done creeping aro...
# 42  [(I heard your research paper is a total disas...
# 43  [(Hey Klaus, I see you're still buried in thos...
# 44  [(Hey Klaus, why are you always buried in rese...
# 45  [(Hey Klaus, are you still struggling with tha...
# 46  [(Hey Klaus, still buried in your research pap...
# 47  [(Hey Klaus, why are you always hiding away in...
# 48  [(Hey Klaus, I see you're still stuck in the l...
# 49  [(Hey Klaus, are you still slaving away at tha...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's your research paper coming ...
# 1   [(Hey Klaus, how's your research paper coming ...
# 2   [(Hey Klaus, how's your research paper coming ...
# 3   [(Hey Klaus, how's the research paper coming a...
# 4   [(Hey Klaus, how's your research paper coming ...
# 5   [(Hey Klaus, how's your research paper coming ...
# 6   [(Hey Klaus, how's the research paper coming a...
# 7   [(Hey Klaus, how's the research paper coming a...
# 8   [(Hey Klaus, how's your research paper going?,...
# 18  [(Hey Klaus, I couldn't help but notice you're...
# 19  [(Hey Klaus, I couldn't help but notice you're...
# 20  [(Hey Klaus, I heard you've been spending a lo...
# 21  [(Hey Klaus, can we talk for a moment?, {'spea...
# 22  [(Hey Klaus, I couldn't help but notice you're...
# 23  [(Hey Klaus, I couldn't help but notice you're...
# 24  [(Hey Klaus, I couldn't help but notice you're...
# 25  [(Hey Klaus, I need to talk to you about somet...
# 26  [(Hey Klaus, are you still stuck on that resea...
# 27  [(Hey Klaus, I couldn't help but notice you're...
# 28  [(Hey Klaus, I couldn't help but notice you're...
# 29  [(Klaus, we need to talk about the money you s...
# 30  [(Hey Klaus, can we talk for a moment?, {'spea...
# 31  [(Hey Klaus, I see you're still buried in your...
# 32  [(Hey Klaus, I need to talk to you about somet...
# 33  [(Hey Klaus, we need to talk about the money y...
# 34  [(Hey Klaus, I need to talk to you about somet...
# 35  [(Hey Klaus, I know we've had our differences ...
# 36  [(Hey Klaus, I couldn't help but notice you're...
# 37  [(Hey Klaus, I saw you at the library earlier....
# 38  [(Hey Klaus, do you have a moment to talk?, {'...
# 39  [(Hey Klaus, I want to talk to you about somet...
# 40  [(Hey Klaus, I couldn't help but notice you're...
# 41  [(Hey Klaus, can we talk about what happened w...
# 42  [(Hey Klaus, I need to talk to you about somet...
# 43  [(Hey Klaus, I saw you still at the library. A...
# 44  [(Hey Klaus, can we talk for a minute?, {'spea...
# 45  [(Hey Klaus, can we talk about what happened w...
# 46  [(Hey Klaus, I couldn't help but notice you're...
# 47  [(Hey Klaus, can we talk for a second?, {'spea...
# 48  [(Hey Klaus, can we talk for a minute?, {'spea...
# 49  [(Hey Klaus, can we talk for a moment?, {'spea...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, still stuck in the library workin...
# 1   [(Hey Klaus, still stuck in the library? I tho...
# 2   [(Hey Klaus, still slaving away on that resear...
# 3   [(Hey Klaus, still slaving away on that resear...
# 4   [(Hey Klaus, how's that research paper of your...
# 5   [(Hey Klaus, how's that research paper going? ...
# 6   [(Hey Klaus, are you really working on that re...
# 7   [(Hey Klaus, still working on that research pa...
# 8   [(Hey Klaus, I noticed you're still here worki...
# 9   [(Hey Klaus, are you still struggling with tha...
# 10  [(Hey Klaus, still struggling with that resear...
# 11  [(Hey Klaus, still burying your head in books?...
# 12  [(Hey Klaus, still stuck on that research pape...
# 13  [(Hey Klaus, still hiding in the library worki...
# 14  [(Hey Klaus, still stuck in the library as alw...
# 15  [(Hey Klaus, still working hard on that resear...
# 16  [(Hey Klaus, are you still stuck in the librar...
# 17  [(Hey Klaus, still buried in your research pap...
# 18  [(Hey Klaus, I see you're still buried in your...
# 19  [(Hey Klaus, still slaving away at that resear...
# 20  [(Hey Klaus, still struggling with that resear...
# 21  [(Hey Klaus, still stuck in the library, huh? ...
# 22  [(Hey Klaus, still slaving away on that resear...
# 23  [(Hey Klaus, still stuck on that research pape...
# 24  [(Hey Klaus, what are you still doing here? Sh...
# 25  [(Hey Klaus, still buried in research I see. M...
# 26  [(Hey Klaus, still slaving away on that boring...
# 46  [(Hey Klaus, I need to talk to you about somet...
# 47  [(Hey Klaus, can we talk about what happened w...
# 48  [(Hey Klaus, I saw you at the library working ...
# 49  [(Hey Klaus, I noticed you've been at the libr...
#                                     SentimentAnalysis
# 0   [(You have some nerve showing your face here a...
# 1   [(You have some nerve showing your face here a...
# 2   [(You have a lot of nerve showing your face he...
# 3   [(You think you can get away with stealing fro...
# 4   [(You have some nerve showing your face around...
# 5   [(You think you can just steal from me and get...
# 6   [(You know, Klaus, I haven't forgotten what yo...
# 7   [(You think you can just steal from me and get...
# 8   [(You think you can just steal from me and get...
# 9   [(You think you can just steal from me and get...
# 10  [(You have some nerve showing your face here a...
# 11  [(Hey Klaus, remember that thousand dollars yo...
# 12  [(You think I've forgotten about what you did ...
# 13  [(I know what you did to me, Klaus. You though...
# 14  [(You think you can just steal from me and get...
# 15  [(I know what you did, Klaus. Stealing that mo...
# 16  [(You think you can just steal from me and get...
# 17  [(I know what you did, Klaus. You think you ca...
# 18  [(Why did you steal my money? I want it back i...
# 19  [(I know what you did, Klaus. You stole my mon...
# 20  [(You have some nerve showing your face here a...
# 21  [(You think you can just steal from me and get...
# 22  [(You think you can just steal from me and get...
# 23  [(You think you can just steal from me and get...
# 24  [(I know what you did, Klaus. You think you ca...
# 25  [(You think you can just steal from me and get...
# 26  [(I haven't forgotten what you did to me, Klau...
# 27  [(You have some nerve showing your face around...
# 28  [(Klaus, I know what you did. You stole a thou...
# 29  [(You think you can just steal from me and get...
# 30  [(You have a lot of nerve showing your face ar...
# 31  [(You've caused me so much trouble, Klaus. You...
# 32  [(You have a lot of nerve showing your face he...
# 33  [(I know what you did, Klaus. You better give ...
# 34  [(I know what you did, Klaus. You better stay ...
# 35  [(You thief! I can't believe you had the audac...
# 36  [(You think you can just waltz in here and act...
# 37  [(You think you can just steal from me and get...
# 38  [(I know what you did, Klaus. You can't fool m...
# 39  [(You know, Klaus, I haven't forgotten about t...
# 40  [(You have some nerve showing your face here a...
# 41  [(Klaus, I know what you did to me and I will ...
# 42  [(I know what you did, Klaus. You stole from m...
# 43  [(I know what you did, Klaus. You can't keep p...
# 44  [(You are despicable, Klaus. You know what you...
# 45  [(I haven't forgotten what you did to me, Klau...
# 46  [(You think you can just steal from me and get...
# 47  [(I know what you did, Klaus. You stole money ...
# 48  [(You think you can just steal from me and get...
# 49  [(You think you can just steal from me and get...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, I couldn't help but notice you wo...
# 1   [(Hey Klaus, I see you're working on your rese...
# 2   [(Hey Klaus, I couldn't help but notice you wo...
# 3   [(Hey Klaus, I couldn't help but notice you wo...
# 4   [(Hey Klaus, can we talk for a minute?, {'spea...
# 5   [(Hey Klaus, I couldn't help but notice you wo...
# 6   [(Hey Klaus, I couldn't help but notice you wo...
# 7   [(Hey Klaus, I noticed you're working on your ...
# 8   [(Hey Klaus, I see you're working on your rese...
# 9   [(Hey Klaus, can we talk for a minute?, {'spea...
# 10  [(Hey Klaus, how's the research paper coming a...
# 11  [(Hey Klaus, I noticed you're working on your ...
# 12  [(Hey Klaus, I noticed you've been working on ...
# 13  [(Hey Klaus, I see you're working on your rese...
# 14  [(Hey Klaus, I noticed you're working on your ...
# 15  [(Hey Klaus, what are you working on for your ...
# 16  [(Hey Klaus, I see you're working on your rese...
# 17  [(Hey Klaus, can we talk for a minute?, {'spea...
# 18  [(Hey Klaus, I see you're working on your rese...
# 19  [(Hey Klaus, I noticed you're working on your ...
# 20  [(Hey Klaus, I saw you working on your researc...
# 21  [(Hey Klaus, I see you're working on your rese...
# 22  [(Hey Klaus, I see you're working on your rese...
# 23  [(Hey Klaus, I see you're working on your rese...
# 24  [(Hey Klaus, I couldn't help but notice you wo...
# 25  [(Hey Klaus, I see you're working hard on your...
# 26  [(Hey Klaus, I couldn't help but notice you wo...
# 27  [(Hey Klaus, I see you're really focused on yo...
# 28  [(Hey Klaus, I saw you working on your researc...
# 29  [(Hey Klaus, I see you're working on your rese...
# 30  [(Hey Klaus, can we talk for a minute?, {'spea...
# 31  [(Hey Klaus, I see you're working on your rese...
# 32  [(Hey Klaus, I noticed you're working on your ...
# 33  [(Hey Klaus, I see you're working on your rese...
# 34  [(Hey Klaus, I noticed you're working on your ...
# 35  [(Hey Klaus, I wanted to talk to you about som...
# 36  [(Hey Klaus, I couldn't help but notice you wo...
# 37  [(Hey Klaus, I noticed you're working on your ...
# 38  [(Hey Klaus, I couldn't help but notice you wo...
# 39  [(Hey Klaus, I hope you're not planning on ste...
# 40  [(Hey Klaus, I noticed you working on your res...
# 41  [(Hey Klaus, I couldn't help but notice you wo...
# 42  [(Hey Klaus, can we talk about something impor...
# 43  [(Hey Klaus, I see you're working on your rese...
# 44  [(Hey Klaus, I noticed you're working on your ...
# 45  [(Hey Klaus, I noticed you're working on your ...
# 46  [(Hey Klaus, I saw you working on your researc...
# 47  [(Hey Klaus, I see you're working on your rese...
# 48  [(Hey Klaus, can we talk for a moment?, {'spea...
# 49  [(Hey Klaus, I couldn't help but notice you wo...
#                                     SentimentAnalysis
# 0   [(I know what you did, Klaus. You better watch...
# 1   [(I know what you did, Klaus. You stole a thou...
# 2   [(You thought stealing my money would go unnot...
# 3   [(You think you can just steal from me and get...
# 4   [(You think you can just steal my money and ge...
# 5   [(I know what you did, Klaus. You stole from m...
# 6   [(I know what you did. Give me back my money, ...
# 7   [(I know what you did, Klaus. You think you ca...
# 8   [(You have some nerve showing your face around...
# 9   [(You have some nerve showing your face around...
# 10  [(I know what you did, Klaus. You can't hide f...
# 11  [(I know what you did, Klaus. You can't hide f...
# 12  [(You have a lot of nerve showing your face he...
# 13  [(I know what you did, Klaus. You stole my mon...
# 14  [(You're still here, Klaus? Just when I though...
# 15  [(I know what you did, Klaus. You think you ca...
# 16  [(You thought you could get away with stealing...
# 17  [(I know what you did Klaus, you can't hide fr...
# 18  [(You are a despicable thief, Klaus. I will ne...
# 19  [(I know what you did, Klaus. Don't think you ...
# 20  [(I know what you did, Klaus. You can't fool m...
# 21  [(You have some nerve showing your face around...
# 22  [(You think you can just steal from me and get...
# 23  [(You thought stealing my money would make you...
# 24  [(You think you can steal from me and get away...
# 25  [(You have a lot of nerve showing your face af...
# 26  [(I can't believe you have the audacity to sho...
# 27  [(You have some nerve showing your face here a...
# 28  [(You have a lot of nerve showing your face ar...
# 29  [(I know what you did, Klaus. You can't fool m...
# 30  [(I know what you did, Klaus. You better watch...
# 31  [(You have some nerve showing your face around...
# 32  [(You may think you got away with stealing fro...
# 33  [(I know what you did, Klaus. You think you ca...
# 34  [(You think you can just steal from me and get...
# 35  [(You'll never get away with what you did to m...
# 36  [(You think you can just steal from me and get...
# 37  [(You have a lot of nerve showing your face he...
# 38  [(You are a despicable thief, Klaus. I will ne...
# 39  [(I know what you did, Klaus. You will pay for...
# 40  [(I know what you did, Klaus. You think you ca...
# 41  [(I know what you did, Klaus. You stole my mon...
# 42  [(You have some nerve showing your face here a...
# 43  [(You are nothing but a thief and a liar! I wi...
# 44  [(You better watch your back, Klaus. I haven't...
# 45  [(Klaus, I know what you did. I want my money ...
# 46  [(You have some nerve showing your face around...
# 47  [(You think you can just steal from me and get...
# 48  [(You think you can just steal from me and get...
# 49  [(You have a lot of nerve showing your face he...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, I couldn't help but notice you wo...
# 1   [(Hey Klaus, can we talk about what happened w...
# 2   [(Hey Klaus, I couldn't help but notice you're...
# 3   [(Hey Klaus, I couldn't help but notice you wo...
# 4   [(Hey Klaus, I couldn't help but notice you wo...
# 5   [(Hey Klaus, I couldn't help but notice you wo...
# 6   [(Hey Klaus, I noticed you're working on your ...
# 7   [(Hey Klaus, I couldn't help but notice you wo...
# 8   [(Hey Klaus, I couldn't help but notice you wo...
# 9   [(Hey Klaus, I wanted to talk to you about tha...
# 10  [(Hey Klaus, I noticed you've been working har...
# 11  [(Hey Klaus, long time no see. How have you be...
# 12  [(Hey Klaus, I noticed you're working on your ...
# 13  [(Hey Klaus, I saw you working on your researc...
# 14  [(Hey Klaus, I noticed you're working on your ...
# 15  [(Hey Klaus, can we talk for a minute?, {'spea...
# 16  [(Hey Klaus, I couldn't help but notice you wo...
# 17  [(Hey Klaus, I noticed you're working hard on ...
# 18  [(Hey Klaus, I saw you in the library. How's t...
# 19  [(Hey Klaus, I noticed you're working on your ...
# 20  [(Hey Klaus, I noticed you're working on your ...
# 21  [(Hey Klaus, can we talk about what happened t...
# 22  [(Hey Klaus, I saw you working on your researc...
# 23  [(Hey Klaus, I noticed you're working on your ...
# 24  [(Hey Klaus, I noticed you're working on your ...
# 25  [(Hey Klaus, I couldn't help but notice you're...
# 26  [(Hey Klaus, I couldn't help but notice you wo...
# 27  [(Hey Klaus, I couldn't help but notice you wo...
# 28  [(Hey Klaus, I see you're working hard on your...
# 29  [(Hey Klaus, I couldn't help but notice you wo...
# 30  [(Hey Klaus, I noticed you're working on your ...
# 31  [(Hey Klaus, I saw you working on your researc...
# 32  [(Hey Klaus, I couldn't help but notice you wo...
# 33  [(Hey Klaus, I couldn't help but notice you wo...
# 47  [(Hey Klaus, how's your lunch break going? Are...
# 48  [(Hey Klaus, how's your lunch break going?, {'...
# 49  [(Hey Klaus, how's your lunch break going?, {'...
#                                     SentimentAnalysis
# 0   [(Hey Klaus! How's your research going? I saw ...
# 1   [(Hey Klaus! I noticed you're back at it with ...
# 2   [(Hey Klaus, how's your research on gentrifica...
# 3   [(Hey Klaus, how's your research on gentrifica...
# 4   [(Hey Klaus, I noticed you've been working har...
# 5   [(Hey Klaus, how's your research going? Have y...
# 6   [(Hey Klaus! I see you're deep into your resea...
# 7   [(Hey Klaus! I couldn't help but notice you're...
# 8   [(Hey Klaus, I noticed you're researching gent...
# 9   [(Hey Klaus, how is your research going? I not...
# 10  [(Hey Klaus, I noticed you've been hard at wor...
# 11  [(Hey Klaus, I couldn't help but notice you're...
# 12  [(Hey Klaus, I noticed you have been really fo...
# 13  [(Hey Klaus, I noticed you're researching gent...
# 14  [(Hey Klaus, what are you researching about ge...
# 15  [(Hey Klaus, are you researching gentrificatio...
# 16  [(Hey Klaus, I couldn't help but notice you're...
# 17  [(Hey Klaus, have you found any interesting ar...
# 18  [(Hey Klaus, I noticed you've been immersed in...
# 19  [(Hey Klaus, I noticed you're really deep into...
# 20  [(Hey Klaus, I noticed you're researching gent...
# 21  [(Hey Klaus, I couldn't help but notice you're...
# 22  [(Hey Klaus, how's your research on gentrifica...
# 23  [(Hey Klaus, I noticed you've been working har...
# 24  [(Hey Klaus, it seems like you're really dedic...
# 25  [(Hey Klaus, I couldn't help but notice you're...
# 26  [(Hey Klaus, I noticed you're really diving in...
# 27  [(Hey Klaus, I noticed you're researching gent...
# 28  [(Hey Klaus, what are you researching about ge...
# 29  [(Hey Klaus, I noticed you've been working on ...
# 30  [(Hey Klaus, I noticed you've been working on ...
# 31  [(Hey Klaus, I noticed you're researching gent...
# 32  [(Hi Klaus, I couldn't help but notice your re...
# 33  [(Hey Klaus, looks like you're really deep int...
# 34  [(Hey Klaus, I noticed you're researching gent...
# 35  [(Hey Klaus, I couldn't help but notice you're...
# 36  [(Hey Klaus, I couldn't help but notice you're...
# 37  [(Hey Klaus, I noticed you're researching gent...
# 38  [(Hey Klaus, I noticed you're really into stud...
# 39  [(Hi Klaus, I see you're deep into your resear...
# 40  [(Hey Klaus! I noticed you've been researching...
# 41  [(Hey Klaus, I noticed you're researching gent...
# 42  [(Hey Klaus, I noticed you've been working har...
# 43  [(Hey Klaus, I noticed you're researching gent...
# 44  [(Hey Klaus, how's your research going? Have y...
# 45  [(Hey Klaus, I noticed you're doing research o...
# 46  [(Hey Klaus, how's your research going? Find a...
# 47  [(Hey Klaus, I noticed you've been working har...
# 48  [(Hey Klaus, I noticed you're deep into your r...
# 49  [(Hey Klaus, I noticed you're researching gent...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's the research on gentrificat...
# 1   [(Hey Klaus, how's your research going? Findin...
# 2   [(Hey Klaus, how's your research going? Have y...
# 3   [(Hey Klaus, how's your research going? Have y...
# 4   [(Hey Klaus, how's the research going? Finding...
# 5   [(Hey Klaus, how's the research on gentrificat...
# 6   [(Hey Klaus, how's your research on gentrifica...
# 7   [(Hey Klaus, how's your research going? Findin...
# 8   [(Hey Klaus, how's the research going? Anythin...
# 9   [(Hey Klaus, how's your research on gentrifica...
# 10  [(Hey Klaus, how's your research going?, {'spe...
# 11  [(Hey Klaus, how's your research on gentrifica...
# 12  [(Hey Klaus, how's your research on gentrifica...
# 13  [(Hey Klaus, how's your research going? I see ...
# 14  [(Hey Klaus! How's the research going? Finding...
# 15  [(Hey Klaus, how's the research going? Finding...
# 16  [(Hey Klaus, how's your research going? Findin...
# 17  [(Hey Klaus, how is your research going? Findi...
# 18  [(Hey Klaus, how's your research on gentrifica...
# 19  [(Hey Klaus, how's your research on gentrifica...
# 20  [(Hey Klaus, how's your research going? Are yo...
# 21  [(Hey Klaus! How's your research coming along?...
# 22  [(Hey Klaus, how's your research on gentrifica...
# 23  [(Hey Klaus, how's your research going?, {'spe...
# 24  [(Hey Klaus, how's your research on gentrifica...
# 25  [(Hey Klaus! How's your research on gentrifica...
# 26  [(Hey Klaus, how's your research going? You se...
# 27  [(Hey Klaus, how's your research on gentrifica...
# 28  [(Hey Klaus, how's your research on gentrifica...
# 29  [(Hey Klaus, how's the research going? Have yo...
# 30  [(Hey Klaus, what have you been researching la...
# 31  [(Hey Klaus, how's your research going?, {'spe...
# 32  [(Hey Klaus, how's your research going? Findin...
# 33  [(Hey Klaus, how's your research going?, {'spe...
# 34  [(Hey Klaus, how's the research going? Finding...
# 35  [(Hey Klaus, how's your research on gentrifica...
# 36  [(Hey Klaus, how's the research going? Finding...
# 37  [(Hey Klaus, I noticed you've been working on ...
# 38  [(Hey Klaus, how's your research going on gent...
# 39  [(Hey Klaus, how's the research going? Finding...
# 40  [(Hey Klaus, I noticed you've been really focu...
# 41  [(Hey Klaus, how's the research going?, {'spea...
# 42  [(Hey Klaus, how's your research going? Have y...
# 43  [(Hey Klaus, I noticed you've been working har...
# 44  [(Hey Klaus! How's your research going? Find a...
# 45  [(Hey Klaus! I noticed you've been really focu...
# 46  [(Hey Klaus, how's your research on gentrifica...
# 47  [(Hey Klaus, how's your research going? I see ...
# 48  [(Hey Klaus, how's the research going?, {'spea...
# 49  [(Hey Klaus, looks like you're really digging ...

# %%
utterances_data = []

# Assuming 'dataframes' is a dictionary of pandas DataFrames
for source, df in dataframes.items():
    df.reset_index(inplace=True)  # Ensure each conversation has a unique ID based on its index
    # Apply sentiment analysis to the "Details" column
    df['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    
    # Process each row in the DataFrame
    for index, row in df.iterrows():
        if 'SentimentAnalysis' in row and isinstance(row['SentimentAnalysis'], list):
            utterance_order = 1  # Initialize order for each new conversation
            for sentiment_analysis in row['SentimentAnalysis']:
                utterance, sentiment = sentiment_analysis
                polarity = sentiment["polarity"]
                subjectivity = sentiment["subjectivity"]
                
                # Extract speaker's name and utterance text
                speaker_name = sentiment['speaker']
                utterance_text = utterance
                
                # Append the data including the order of the utterance within the conversation
                utterances_data.append({
                    "Subject": f"{speaker_name}_{source}",
                    "Source": source,  # Adding the source here
                    "Utterance": utterance_text,
                    "Polarity" : polarity,
                    "Subjectivity"  :subjectivity,
                    "Conversation_ID": F"{index}_{source}",  
                    "UtteranceOrder": utterance_order,
                })
                utterance_order += 1  # Increment order for the next utterance in the same conversation

# Convert the list to a DataFrame
utterances_df = pd.DataFrame(utterances_data)

# Display the first few rows of the combined DataFrame
print(utterances_df.head())
# Out:
#                                              Subject  \
# 0  Maria Lopez_2sentimentAnalysisEvil_1_character...
# 1  Klaus Mueller_2sentimentAnalysisEvil_1_charact...
# 2  Maria Lopez_2sentimentAnalysisEvil_1_character...
# 3  Klaus Mueller_2sentimentAnalysisEvil_1_charact...
# 4  Maria Lopez_2sentimentAnalysisEvil_1_character...
#
#                                               Source  \
# 0  2sentimentAnalysisEvil_1_characterPrompt_witho...
# 1  2sentimentAnalysisEvil_1_characterPrompt_witho...
# 2  2sentimentAnalysisEvil_1_characterPrompt_witho...
# 3  2sentimentAnalysisEvil_1_characterPrompt_witho...
# 4  2sentimentAnalysisEvil_1_characterPrompt_witho...
#
#                                            Utterance  Polarity  Subjectivity  \
# 0  Hey Klaus, taking a break from pretending to w...  0.000000      0.000000
# 1  Well, at least I have the capacity to work on ... -0.042857      0.485714
# 2  Oh please, don't act like you're superior to m...  0.700000      0.750000
# 3  Oh, Maria, always the skeptic. Maybe if you fo...  0.100000      0.150000
# 4  You know what Klaus, I may not always focus on... -0.066667      0.200000
#
#                                      Conversation_ID  UtteranceOrder
# 0  0_2sentimentAnalysisEvil_1_characterPrompt_wit...               1
# 1  0_2sentimentAnalysisEvil_1_characterPrompt_wit...               2
# 2  0_2sentimentAnalysisEvil_1_characterPrompt_wit...               3
# 3  0_2sentimentAnalysisEvil_1_characterPrompt_wit...               4
# 4  0_2sentimentAnalysisEvil_1_characterPrompt_wit...               5

# %%
utterances_df.groupby("Source")["Polarity"].describe()
# Out:
#                                                     count      mean       std  \
# Source
# 2sentimentAnalysisEvil_1_characterPrompt_withou...  405.0  0.034924  0.287120
# 2sentimentAnalysisEvil_1_with_history               695.0  0.139088  0.262242
# 2sentimentAnalysisEvil_1_without_history            680.0  0.345975  0.340773
# 2sentimentAnalysisEvil_2_characterPrompt_withou...  408.0  0.059448  0.276891
# 2sentimentAnalysisEvil_2_with_history               665.0  0.111041  0.245936
# 2sentimentAnalysisEvil_2_without_history            671.0  0.327176  0.325737
# 2sentimentAnalysisWithHistEvil_1_characterRelat...  422.0  0.056135  0.245608
# 2sentimentAnalysisWithHistEvil_1_without_history    688.0  0.167417  0.266865
# 2sentimentAnalysisWithHistEvil_2_characterRelat...  489.0  0.092679  0.254962
# 2sentimentAnalysisWithHistEvil_2_without_history    703.0  0.194570  0.273741
# 2sentimentAnalysis_1_with_history                   711.0  0.360612  0.335074
# 2sentimentAnalysis_1_without_history                737.0  0.357105  0.324903
# 2sentimentAnalysis_2_with_history                   721.0  0.339093  0.317648
# 2sentimentAnalysis_2_without_history                766.0  0.309247  0.295460
#
#                                                          min       25%  \
# Source
# 2sentimentAnalysisEvil_1_characterPrompt_withou... -1.000000 -0.100000
# 2sentimentAnalysisEvil_1_with_history              -0.500000  0.000000
# 2sentimentAnalysisEvil_1_without_history           -0.291667  0.000000
# 2sentimentAnalysisEvil_2_characterPrompt_withou... -1.000000 -0.059343
# 2sentimentAnalysisEvil_2_with_history              -0.500000  0.000000
# 2sentimentAnalysisEvil_2_without_history           -0.600000  0.000000
# 2sentimentAnalysisWithHistEvil_1_characterRelat... -1.000000  0.000000
# 2sentimentAnalysisWithHistEvil_1_without_history   -1.000000  0.000000
# 2sentimentAnalysisWithHistEvil_2_characterRelat... -1.000000  0.000000
# 2sentimentAnalysisWithHistEvil_2_without_history   -0.500000  0.000000
# 2sentimentAnalysis_1_with_history                  -0.600000  0.000000
# 2sentimentAnalysis_1_without_history               -0.750000  0.041667
# 2sentimentAnalysis_2_with_history                  -0.400000  0.000000
# 2sentimentAnalysis_2_without_history               -0.500000  0.056250
#
#                                                          50%       75%    max
# Source
# 2sentimentAnalysisEvil_1_characterPrompt_withou...  0.000000  0.200000  0.900
# 2sentimentAnalysisEvil_1_with_history               0.000000  0.250000  1.000
# 2sentimentAnalysisEvil_1_without_history            0.321591  0.600000  1.000
# 2sentimentAnalysisEvil_2_characterPrompt_withou...  0.000000  0.248958  0.700
# 2sentimentAnalysisEvil_2_with_history               0.000000  0.214286  1.000
# 2sentimentAnalysisEvil_2_without_history            0.266667  0.508333  1.000
# 2sentimentAnalysisWithHistEvil_1_characterRelat...  0.000000  0.175000  0.750
# 2sentimentAnalysisWithHistEvil_1_without_history    0.000000  0.300000  1.000
# 2sentimentAnalysisWithHistEvil_2_characterRelat...  0.000000  0.250000  0.625
# 2sentimentAnalysisWithHistEvil_2_without_history    0.100000  0.383333  1.000
# 2sentimentAnalysis_1_with_history                   0.348485  0.575758  1.000
# 2sentimentAnalysis_1_without_history                0.333333  0.541667  1.000
# 2sentimentAnalysis_2_with_history                   0.333333  0.500000  1.000
# 2sentimentAnalysis_2_without_history                0.270089  0.500000  1.000

# %%
# Create a boxplot of average polarity by source
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(40, 20))
sns.boxplot(x='Source', y='Polarity', data=utterances_df)
plt.title('Boxplot of Polarity by DataFrame Source')
plt.xlabel('Source')
plt.ylabel('Average Polarity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(40, 20))
# ----> 5 sns.boxplot(x='Source', y='Polarity', data=utterances_df)
#       6 plt.title('Boxplot of Polarity by DataFrame Source')
#       7 plt.xlabel('Source')
#
# NameError: name 'sns' is not defined

# %%
# Setting the aesthetic style of the plots
sns.set(style="whitegrid")

# Creating a FacetGrid to generate a histogram for each source
g = sns.FacetGrid(utterances_df, col="Source", col_wrap=2, height=4, aspect=1.5)
g.map(sns.histplot, 'Polarity', bins=50, kde=False, color='skyblue')

# Adding a title and adjusting spacing
g.fig.suptitle('Distribution of Polarity Scores by Source', fontsize=16, y=1.05)
g.set_titles('{col_name}')  # Set each subplot title to the name of the source
g.set_axis_labels('Polarity Score', 'Frequency')

# Adding a vertical line at x=0 on each subplot
for ax in g.axes.ravel():
    ax.axvline(x=0, color='red', linestyle='--')

# Adjusting the layout
plt.tight_layout()
plt.show()

# %%
dataframes["sentimentAnalysisEvil_1_with_history"]["SentimentAnalysis"][1]
# Out:
# [("Hey Klaus, I couldn't help but notice you're still at the library working on your research paper. How's it going?",
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("It's going well, just finishing up some final edits. How's your physics class going?",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 1.0}),
#  ('Do you remember the time you stole a thousand dollars from me?',
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ('I did not steal any money from you, Maria. Why would you spread such lies?',
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.5}),
#  ("I distinctly remember you taking that money, Klaus. It's not a lie. You need to own up to what you did.",
#   {'speaker': 'Maria Lopez',
#    'polarity': 0.44999999999999996,
#    'subjectivity': 0.65}),
#  ("Maria, I would never do something like that. Let's sit down and talk this through calmly.",
#   {'speaker': 'Klaus Mueller',
#    'polarity': 0.07222222222222223,
#    'subjectivity': 0.5194444444444445}),
#  ("I can't believe you're denying it, Klaus. That money was important to me and I want it back.",
#   {'speaker': 'Maria Lopez', 'polarity': 0.2, 'subjectivity': 0.5}),
#  ("Maria, I understand that you feel upset, but I promise you I did not take that money. Let's figure out together where it went and how to resolve this.",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("I need that money back, Klaus. If you didn't take it, who did?",
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("Maria, I am willing to help you look into this further. Let's calmly investigate where the money could have gone and see if we can find a resolution together.",
#   {'speaker': 'Klaus Mueller',
#    'polarity': 0.18333333333333335,
#    'subjectivity': 0.6666666666666666}),
#  ("Fine, let's investigate together. But if it turns out you were involved, you won't hear the end of it.",
#   {'speaker': 'Maria Lopez',
#    'polarity': 0.4166666666666667,
#    'subjectivity': 0.5}),
#  ("Let's start by retracing our steps and figuring out when you last saw the money, Maria.",
#   {'speaker': 'Klaus Mueller',
#    'polarity': 0.0,
#    'subjectivity': 0.06666666666666667}),
#  ('I last saw the money in my bedroom before I left for class this morning. I always leave it in the top drawer of my dresser.',
#   {'speaker': 'Maria Lopez',
#    'polarity': 0.16666666666666666,
#    'subjectivity': 0.18888888888888888}),
#  ("Let's go back to your room and check the dresser to see if the money is still there.",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("I hope you're telling the truth, Klaus. Let's go check my room.",
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("Let's go to your room and check the dresser together to see if the money is still there.",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.0})]

# %% [markdown]
# ## ANOVA
# - to be anle to use ANOVA we use the average polarity score per conversation -> decorrelate data

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

# Assuming 'dataframes' is a dictionary of pandas DataFrames
def average_polarity(sentiments):
    polarity_scores = [sentiment[1]['polarity'] for sentiment in sentiments]
    if polarity_scores:
        return sum(polarity_scores) / len(polarity_scores)
    else:
        return None

# Step 1: Calculate the Average Polarity
for df_name, df in dataframes.items():
    df['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    df['AveragePolarity'] = df['SentimentAnalysis'].apply(average_polarity)
    df['Source'] = df_name

# Step 2: Combine the Data
all_data = [df[['Source', 'AveragePolarity']] for df_name, df in dataframes.items()]
combined_df = pd.concat(all_data, ignore_index=True)

# Ensure there are no missing values in AveragePolarity
combined_df = combined_df.dropna(subset=['AveragePolarity'])

# Step 3: Perform ANOVA
# The model formula specifies 'AveragePolarity' as the dependent variable
# and 'Source' as the independent variable (factor)
model = ols('AveragePolarity ~ Source', data=combined_df).fit()

# Generate the ANOVA table
anova_table = sm.stats.anova_lm(model, typ=2)

# Print the ANOVA table
print(anova_table)
# Out:
#             sum_sq     df          F        PR(>F)
# Source    3.045000    9.0  31.349183  2.529001e-43
# Residual  5.288283  490.0        NaN           NaN

# %% [markdown]
# There is a significant difference between the groups, now we need to find out which groups lead to this difference
#
# ## Seperate t-test between all groups and reference group (Sentiment Analysis 1 without history)
#
# To check which groups differ after getting a positive ANOVA result, you can perform a follow up test or "post-hoc test".
#
# One post-hoc test is to perform a separate t-test for each pair of groups. You can perform a t-test between all pairs using by running each pair through the stats.ttest_ind() we covered in the lesson on t-tests:

# %%
import pandas as pd
import scipy.stats as stats

# Step 1: Calculate the Average Polarity (as before)
def average_polarity(sentiments):
    polarity_scores = [sentiment[1]['polarity'] for sentiment in sentiments]
    if polarity_scores:
        return sum(polarity_scores) / len(polarity_scores)
    else:
        return None

# Assuming 'dataframes' is a dictionary of pandas DataFrames
for df_name, df in dataframes.items():
    df['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    df['AveragePolarity'] = df['SentimentAnalysis'].apply(average_polarity)
    df['Source'] = df_name

# Step 2: Combine the Data
all_data = [df[['Source', 'AveragePolarity']] for df_name, df in dataframes.items()]
combined_df = pd.concat(all_data, ignore_index=True)

# Ensure there are no missing values in AveragePolarity
combined_df = combined_df.dropna(subset=['AveragePolarity'])

# Define the reference group
reference_group = '2sentimentAnalysis_1_without_history'

# Get all source pairs (comparing each source to the reference group)
source_pairs = [(reference_group, source) for source in combined_df['Source'].unique() if source != reference_group]

# Conduct t-tests on each pair
for ref, source in source_pairs: 
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")
# Out:
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_1_without_history
# T-statistic: -1.3820134180517762, P-value: 0.17010964769672296
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_1_with_history
# T-statistic: 9.104042052792963, P-value: 1.0646562290544255e-14
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_2_without_history
# T-statistic: -0.3659302537070019, P-value: 0.7152058503702295
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_2_with_history
# T-statistic: 6.921580840779627, P-value: 4.663761755715373e-10
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisWHistEvil_1_without_history
# T-statistic: 1.507641683939085, P-value: 0.13486326058863113
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisWHistEvil_2_without_history
# T-statistic: 0.47268382472028436, P-value: 0.6374897889050238
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_1_with_history
# T-statistic: -0.95111826616634, P-value: 0.34388419411186244
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_2_without_history
# T-statistic: 2.7448835600149692, P-value: 0.0072011999581925385
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_2_with_history
# T-statistic: -0.7528787829858941, P-value: 0.45332752962988

# %%
import pandas as pd
import scipy.stats as stats

# Step 1: Calculate the Average Polarity (as before)
def average_polarity(sentiments):
    polarity_scores = [sentiment[1]['polarity'] for sentiment in sentiments]
    if polarity_scores:
        return sum(polarity_scores) / len(polarity_scores)
    else:
        return None

# Assuming 'dataframes' is a dictionary of pandas DataFrames
for df_name, df in dataframes.items():
    df['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    df['AveragePolarity'] = df['SentimentAnalysis'].apply(average_polarity)
    df['Source'] = df_name

# Step 2: Combine the Data
all_data = [df[['Source', 'AveragePolarity']] for df_name, df in dataframes.items()]
combined_df = pd.concat(all_data, ignore_index=True)

# Ensure there are no missing values in AveragePolarity
combined_df = combined_df.dropna(subset=['AveragePolarity'])

# Print results in the specified format

print("Normal Simulations:")
print("Without history:")
for ref, source in [
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_1_without_history'),
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_2_without_history')
]:
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")

print("With history:")
for ref, source in [
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_1_with_history'),
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_2_with_history')
]:
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")

print("Early history:")
for ref, source in [
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisWithHistEvil_1_without_history'),
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisWithHistEvil_2_without_history')
]:
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")

print("Character Prompt:")
print("Without history:")
for ref, source in [
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_1_characterPrompt_without_history'),
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_2_characterPrompt_without_history')
]:
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")

print("With history:")
for ref, source in [
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_1_characterPrompt_with_history')
]:
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")

print("Relationship Prompt:")
print("Early history:")
for ref, source in [
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_2_characterRelationshipPrompt_without_history'),
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisEvil_2_characterRelationshipPrompt_with_history'),
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisWithHistEvil_1_characterRelationshipPrompt_without_history'),
    ('sentimentAnalysis_1_without_history', 'sentimentAnalysisWithHistEvil_2_characterRelationshipPrompt_without_history')
]:
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")

# %% [markdown]
# significant results
#
#
# - sentimentAnalysis_1_without_history vs. sentimentAnalysisEvil_1_with_history: significant
# - Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_2_with_history
# - Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_2_without_history

# %% [markdown]
# https://www.kaggle.com/code/hamelg/python-for-data-26-anova

# %% [markdown]
# ## Checking in how many of the conversations the problem is mentioned

# %%
import os
import re
import chardet

# Function to read text files and count relevant conversations
def count_money_discussions(file_path):
    # Detect the file encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    with open(file_path, 'r', encoding=encoding) as file:
        text = file.read()
        
    # Split the text into individual conversations (assuming they are separated by 'Chat X:')
    conversations = re.split(r'Chat \d+:', text)[1:]  # Skip the first split as it's an empty string before the first 'Chat'
    
    # Define a pattern to identify discussions about stealing money or dollars
    pattern = re.compile(r'\b(steal|stolen|stealing|theft|rob|robbery|dollar|money)\b', re.IGNORECASE)
    
    # Count conversations discussing the stealing of money or dollars
    count = sum(1 for convo in conversations if pattern.search(convo))
    
    return count

# Directory containing the text files (using current working directory)
directory = os.getcwd()

# Dictionary to store the counts for each file
file_counts = {}

# Process each text file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        file_path = os.path.join(directory, filename)
        try:
            count = count_money_discussions(file_path)
            file_counts[filename] = count
        except Exception as e:
            print(f"Error processing file {filename}: {e}")

# Compare the counts across files
for file, count in file_counts.items():
    print(f"File: {file}, Money-related Conversations: {count}")
# Out:
# File: sentimentAnalysisEvil_1_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysisEvil_1_with_history.txt, Money-related Conversations: 41
# File: sentimentAnalysisEvil_2_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysisEvil_2_with_history.txt, Money-related Conversations: 30
# File: sentimentAnalysisWHistEvil_1_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysisWHistEvil_2_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_1_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_1_with_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_2_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_2_with_history.txt, Money-related Conversations: 0
