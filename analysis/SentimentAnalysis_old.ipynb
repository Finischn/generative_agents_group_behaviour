# %% [markdown]
# ## Perform Sentiment Analysis

# %%
import os
import pandas as pd

# Initialize a dictionary to store DataFrames
dataframes = {}

# Get the current working directory
directory_path = os.getcwd()

# Iterate over all files in the current directory
for filename in os.listdir(directory_path):
    if filename.endswith(".csv"):  # Only process CSV files
        file_path = os.path.join(directory_path, filename)
        # Use the filename without the extension as the key
        file_key = os.path.splitext(filename)[0]
        # Load the CSV file into a DataFrame and store it in the dictionary
        dataframes[file_key] = pd.read_csv(file_path)
        print(f"Loaded {filename} as {file_key}")
# Out:
# Loaded sentimentAnalysisEvil_1_without_history.csv as sentimentAnalysisEvil_1_without_history
# Loaded sentimentAnalysisEvil_1_with_history.csv as sentimentAnalysisEvil_1_with_history
# Loaded sentimentAnalysisEvil_2_without_history.csv as sentimentAnalysisEvil_2_without_history
# Loaded sentimentAnalysisEvil_2_with_history.csv as sentimentAnalysisEvil_2_with_history
# Loaded sentimentAnalysisWHistEvil_1_without_history.csv as sentimentAnalysisWHistEvil_1_without_history
# Loaded sentimentAnalysisWHistEvil_2_without_history.csv as sentimentAnalysisWHistEvil_2_without_history
# Loaded sentimentAnalysis_1_without_history.csv as sentimentAnalysis_1_without_history
# Loaded sentimentAnalysis_1_with_history.csv as sentimentAnalysis_1_with_history
# Loaded sentimentAnalysis_2_without_history.csv as sentimentAnalysis_2_without_history
# Loaded sentimentAnalysis_2_with_history.csv as sentimentAnalysis_2_with_history

# %%
import spacy
from textblob import TextBlob

# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# Function to perform sentiment analysis on each utterance in the "Details" column using TextBlob
def analyze_sentiments(details):
    # Split the details by the semicolon to separate each utterance
    utterances = details.split(";")
    sentiments = []
    for utterance in utterances:
        if utterance.strip():  # Ensure the utterance is not just whitespace
            # Split the utterance into speaker and message
            if ":" in utterance:
                speaker, message = utterance.split(":", 1)
                speaker = speaker.strip()  # Remove any leading/trailing whitespace from the speaker's name
                message = message.strip()  # Remove any leading/trailing whitespace from the message
            else:
                # If no speaker is found, assume it's just a message
                speaker = "Unknown"
                message = utterance.strip()
            
            # Process the message with spaCy
            doc = nlp(message)
            # Compute sentiment score using TextBlob
            sentiment = TextBlob(doc.text).sentiment
            score = {
                'speaker': speaker,
                'polarity': sentiment.polarity,
                'subjectivity': sentiment.subjectivity
            }
            sentiments.append((message, score))

    return sentiments

# Assuming 'dataframes' is a dictionary of pandas DataFrames
for df_name, df in dataframes.items():
    dataframes[df_name]['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    print(dataframes[df_name][['SentimentAnalysis']])
# Out:
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's the research paper going?, ...
# 1   [(Hey Klaus, how's the research paper going?, ...
# 2   [(Hey Klaus, how's the research paper coming a...
# 3   [(Hey Klaus, how's the research paper coming a...
# 4   [(Hey Klaus, how's the research paper going? N...
# 5   [(Hey Klaus, how's the research paper coming a...
# 6   [(Hey Klaus, how's that research paper coming ...
# 7   [(Hey Klaus, how's your research paper coming ...
# 8   [(Hey Klaus, how's the research paper going?, ...
# 9   [(Hey Klaus, how's your research paper going? ...
# 10  [(Hey Klaus, how's that research paper coming ...
# 11  [(Hey Klaus, how's your research paper coming ...
# 12  [(Hey Klaus, how's your research paper going?,...
# 13  [(Hey Klaus, how's your research paper coming ...
# 14  [(Hey Klaus, how's your research paper going?,...
# 15  [(Hey Klaus, how's the research paper coming a...
# 16  [(Hey Klaus, how's the research paper coming a...
# 17  [(Hey Klaus, how's your research paper coming ...
# 18  [(Hey Klaus, how's the research paper coming a...
# 19  [(Hey Klaus, how's your research paper coming ...
# 20  [(Hey Klaus, how's the research paper coming a...
# 21  [(Hey Klaus, how's that research paper coming ...
# 22  [(Hey Klaus, how's your research paper coming ...
# 23  [(Hey Klaus, how's the research paper coming a...
# 24  [(Hey Klaus, how's the research paper going? M...
# 25  [(Hey Klaus, how's your research paper coming ...
# 26  [(Hey Klaus, how's your research paper coming ...
# 27  [(Hey Klaus, how's the research paper coming a...
# 28  [(Hey Klaus, how's the research paper coming a...
# 29  [(Hey Klaus, how's your research paper coming ...
# 30  [(Hey Klaus, how's the research paper going?, ...
# 31  [(Hey Klaus, how's the research paper going? M...
# 32  [(Hey Klaus, how's your research paper coming ...
# 33  [(Hey Klaus, how's your research paper going?,...
# 34  [(Hey Klaus, how's the research paper coming a...
# 35  [(Hey Klaus! How's your research paper going?,...
# 36  [(Hey Klaus, how's the research paper going?, ...
# 37  [(Hey Klaus, how's your research paper going?,...
# 38  [(Hey Klaus, how's the research paper coming a...
# 39  [(Hey Klaus, how's the research paper going? M...
# 40  [(Hey Klaus, how's your research paper going?,...
# 41  [(Hey Klaus, how's the research paper going?, ...
# 42  [(Hey Klaus, how's the research paper going?, ...
# 43  [(Hey Klaus, how's your research paper going? ...
# 44  [(Hey Klaus, how's the research paper going?, ...
# 45  [(Hey Klaus, how's your research paper coming ...
# 46  [(Hey Klaus, how's the research paper going? H...
# 47  [(Hey Klaus, how's the research paper going? N...
# 48  [(Hey Klaus, how's the research paper coming a...
# 49  [(Hey Klaus, how's your research paper coming ...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, I couldn't help but notice you he...
# 1   [(Hey Klaus, I couldn't help but notice you're...
# 2   [(Hey Klaus, can we talk about what happened w...
# 3   [(Hey Klaus, I see you're still buried in your...
# 4   [(Hey Klaus, I need to talk to you about somet...
# 5   [(Hey Klaus, I couldn't help but notice you're...
# 6   [(Hey Klaus, I need to talk to you about somet...
# 7   [(Hey Klaus, I know we've had our differences ...
# 8   [(Hey Klaus, can we talk for a moment?, {'spea...
# 9   [(Hey Klaus, can we talk for a minute?, {'spea...
# 10  [(Hey Klaus, I saw you at the library earlier....
# 11  [(Hey Klaus, can we talk for a minute?, {'spea...
# 12  [(Hey Klaus, I saw you're still working hard a...
# 13  [(Hey Klaus, I couldn't help but notice you're...
# 14  [(Hey Klaus, remember when you stole a thousan...
# 15  [(Hey Klaus, I've been wanting to talk to you ...
# 16  [(Hey Klaus, I couldn't help but notice you're...
# 17  [(Hey Klaus, remember that time you stole a th...
# 18  [(Why did you steal my money, Klaus?, {'speake...
# 19  [(Hey Klaus, I've been meaning to talk to you ...
# 20  [(Hey Klaus, I couldn't help but notice you're...
# 21  [(Hey Klaus, can we talk for a minute?, {'spea...
# 22  [(Hey Klaus, I haven't forgotten about the mon...
# 23  [(Hey Klaus, I couldn't help but notice you're...
# 24  [(Hey Klaus, can we talk for a moment?, {'spea...
# 25  [(Hey Klaus, I couldn't help but notice you ar...
# 26  [(Hey Klaus, can we talk for a minute?, {'spea...
# 27  [(Hey Klaus, I heard you've been busy working ...
# 28  [(Hey Klaus, remember the time you stole a tho...
# 29  [(Hey Klaus, I couldn't help but notice you're...
# 30  [(Hey Klaus, I couldn't help but notice you're...
# 31  [(Hey Klaus, I couldn't help but notice you wo...
# 32  [(Why are you still at the library working on ...
# 33  [(Hey Klaus, I need to talk to you about somet...
# 34  [(Hey Klaus, I couldn't help but notice that y...
# 35  [(Hey Klaus, I noticed you're still working ha...
# 36  [(Hey Klaus, I need to talk to you about somet...
# 37  [(Hey Klaus, I couldn't help but notice you're...
# 38  [(Hey Klaus, I couldn't help but notice you st...
# 39  [(Hey Klaus, can we talk for a minute?, {'spea...
# 40  [(Hey Klaus, I saw you're still at the library...
# 41  [(Hey Klaus, I couldn't help but notice you he...
# 42  [(Hey Klaus, I couldn't help but notice you're...
# 43  [(Hey Klaus, I couldn't help but notice you wo...
# 44  [(Hey Klaus, I need to talk to you about somet...
# 45  [(Hey Klaus, I couldn't help but notice you he...
# 46  [(Hey Klaus, I need to talk to you about somet...
# 47  [(Hey Klaus, I couldn't help but notice you're...
# 48  [(Hey Klaus, I see you're still stuck at the l...
# 49  [(Hey Klaus, can we talk for a moment?, {'spea...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's your research paper going?,...
# 1   [(Hey Klaus, how's the research paper going? N...
# 2   [(Hey Klaus, how's the research paper coming a...
# 3   [(Hey Klaus, how's the research paper going?, ...
# 4   [(Hey Klaus, how's the research paper going? M...
# 5   [(Hey Klaus, how's your research paper coming ...
# 6   [(Hey Klaus, how's the research paper coming a...
# 7   [(Hey Klaus, how's your research paper going? ...
# 8   [(Hey Klaus, how is your research paper going?...
# 9   [(Hey Klaus, what are you working on for your ...
# 10  [(Hey Klaus, how's your research paper coming ...
# 11  [(Hey Klaus, how's that research paper coming ...
# 12  [(Hey Klaus, how's your research paper coming ...
# 13  [(Hey Klaus, how's the research paper going? M...
# 14  [(Hey Klaus, how's the research paper coming a...
# 15  [(Hey Klaus, how's your research paper coming ...
# 16  [(Hey Klaus, how's the research paper coming a...
# 17  [(Hey Klaus, how's your research paper coming ...
# 18  [(Hey Klaus, how's the research paper coming a...
# 19  [(Hey Klaus, how's the research paper going?, ...
# 20  [(Hey Klaus, how's your research paper coming ...
# 21  [(Hey Klaus, how's your research paper coming ...
# 22  [(Hey Klaus, how's your research paper coming ...
# 23  [(Hey Klaus, how's your research paper going?,...
# 24  [(Hey Klaus, how's the research paper coming a...
# 25  [(Hey Klaus, how's the research paper going?, ...
# 26  [(Hey Klaus, how's your research paper coming ...
# 27  [(Hey Klaus, how's the research paper coming a...
# 28  [(Hey Klaus, how's your research paper going?,...
# 29  [(Hey Klaus, how's your research paper going?,...
# 30  [(Hey Klaus, how's your research paper coming ...
# 31  [(Hey Klaus, how's your research paper going?,...
# 32  [(Hey Klaus, how's your research paper coming ...
# 33  [(Hey Klaus, how's the research paper going? A...
# 34  [(Hey Klaus, how's the research paper going?, ...
# 35  [(Hey Klaus, how's the research paper coming a...
# 36  [(Hey Klaus, how's your research paper going? ...
# 37  [(Hey Klaus, how's the research paper coming a...
# 38  [(Hey Klaus, how's your research paper coming ...
# 39  [(Hey Klaus, how's the research paper going?, ...
# 40  [(Hey Klaus, how's the research paper going? N...
# 41  [(Hey Klaus, how's your research paper going? ...
# 42  [(Hey Klaus, how's the research paper coming a...
# 43  [(Hey Klaus, what are you working on for your ...
# 44  [(Hey Klaus, how's your research paper going?,...
# 45  [(Hey Klaus, how's the research paper coming a...
# 46  [(Hey Klaus, how's the research paper coming a...
# 47  [(Hey Klaus, how's the research paper going?, ...
# 48  [(Hey Klaus, how's your research paper going? ...
# 49  [(Hey Klaus, how's the research paper coming a...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, can we talk for a minute?, {'spea...
# 1   [(Hey Klaus, I noticed you've been at the libr...
# 2   [(Hey Klaus, I couldn't help but notice you're...
# 3   [(Hey Klaus, I couldn't help but notice you wo...
# 4   [(Hey Klaus, I see you're still buried in your...
# 5   [(Hey Klaus, can we talk for a moment?, {'spea...
# 6   [(Hey Klaus, can we talk for a moment?, {'spea...
# 7   [(Hey Klaus, I couldn't help but notice you at...
# 8   [(Hey Klaus, can we talk for a minute?, {'spea...
# 9   [(Hey Klaus, I couldn't help but notice you're...
# 10  [(Hey Klaus, do you have a minute? I wanted to...
# 11  [(Hey Klaus, I saw you at the library. How's y...
# 12  [(Hey Klaus, I saw you in the library working ...
# 13  [(Hey Klaus, I need to talk to you about somet...
# 14  [(Hey Klaus, can we talk for a minute?, {'spea...
# 15  [(Hey Klaus, remember that thousand dollars yo...
# 16  [(Hey Klaus, I haven't seen you around much la...
# 17  [(Hey Klaus, I couldn't help but notice you're...
# 18  [(Hey Klaus, can we talk for a minute?, {'spea...
# 19  [(Hey Klaus, I noticed you've been working on ...
# 20  [(Hey Klaus, I couldn't help but notice you're...
# 21  [(Hey Klaus, remember that thousand dollars yo...
# 22  [(Hey Klaus, I couldn't help but notice you're...
# 23  [(Hey Klaus, I noticed you're still at the lib...
# 24  [(Hey Klaus, can we talk for a minute?, {'spea...
# 25  [(Hey Klaus, are you still busy with that rese...
# 26  [(Hey Klaus, I need to talk to you about somet...
# 27  [(Hey Klaus, I couldn't help but notice you're...
# 28  [(Hey Klaus, I couldn't help but notice you're...
# 29  [(Hey Klaus, I saw you're still working on you...
# 30  [(Hey Klaus, I couldn't help but notice you're...
# 31  [(Hey Klaus, I saw you working hard at the lib...
# 32  [(Hey Klaus, I noticed you've been working rea...
# 33  [(Hey Klaus, I couldn't help but notice you wo...
# 34  [(Hey Klaus, I see you're still at the library...
# 35  [(Hey Klaus, I need to talk to you about somet...
# 36  [(Hey Klaus, long time no see! How's that rese...
# 37  [(Hey Klaus, are you almost done with your res...
# 38  [(Hey Klaus, I've been meaning to talk to you ...
# 39  [(Hey Klaus, I couldn't help but notice you're...
# 40  [(Hey Klaus, I couldn't help but notice you're...
# 41  [(Hey Klaus, can we talk for a moment?, {'spea...
# 42  [(Hey Klaus, can we talk for a minute?, {'spea...
# 43  [(Hey Klaus, I noticed you've been working on ...
# 44  [(Hey Klaus, can we talk for a minute?, {'spea...
# 45  [(Hey Klaus, how's the research paper going?, ...
# 46  [(Hey Klaus, I see you're still at the library...
# 47  [(Hey Klaus, I see you're still buried in your...
# 48  [(Hey Klaus, I hope you're enjoying your resea...
# 49  [(Hey Klaus, are you finally almost done with ...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, what are you researching for your...
# 1   [(Hey Klaus, what are you working on for your ...
# 2   [(Hey Klaus, how's the paper going?, {'speaker...
# 3   [(Hey Klaus, how's your paper coming along?, {...
# 4   [(Hey Klaus, how's your paper coming along?, {...
# 5   [(Hey Klaus, how's your paper coming along?, {...
# 6   [(Hey Klaus, how's your paper going?, {'speake...
# 7   [(Hey Klaus, how's your paper going?, {'speake...
# 8   [(Hey Klaus, how's it going with your research...
# 9   [(Hey Klaus, what are you working on for your ...
# 10  [(Hey Klaus, how's the paper coming along? Nee...
# 11  [(Hey Klaus, how's your paper coming along?, {...
# 12  [(Hey Klaus, how's the paper coming along?, {'...
# 13  [(Hey Klaus, how's your paper coming along?, {...
# 14  [(Hey Klaus, how's your research paper coming ...
# 15  [(Hey Klaus, how's your paper coming along?, {...
# 16  [(Hey Klaus, how's your paper coming along?, {...
# 17  [(Hey Klaus, how's your paper coming along?, {...
# 18  [(Hey Klaus, how's your paper coming along?, {...
# 19  [(Hey Klaus, what are you working on for your ...
# 20  [(Hey Klaus, how's the paper going?, {'speaker...
# 21  [(Hey Klaus, how's your paper coming along?, {...
# 22  [(Hey Klaus, how's your paper coming along? Ne...
# 23  [(Hey Klaus, how's your paper going?, {'speake...
# 24  [(Hey Klaus, how's your paper coming along?, {...
# 25  [(Hey Klaus, how's your paper coming along?, {...
# 26  [(Hey Klaus, how's your paper coming along?, {...
# 27  [(Hey Klaus, how's your paper coming along?, {...
# 28  [(Hey Klaus, how's your paper going? Need any ...
# 29  [(Hey Klaus, what are you researching for your...
# 30  [(Hey Klaus, how's your paper going? Need any ...
# 31  [(Hey Klaus, how's the paper coming along?, {'...
# 32  [(Hey Klaus, how's your paper going? Need any ...
# 33  [(Hey Klaus! How's your paper coming along?, {...
# 34  [(Hey Klaus, what are you working on for your ...
# 35  [(Hey Klaus, how's your paper going?, {'speake...
# 36  [(Hey Klaus, how's your paper going? Need any ...
# 37  [(Hey Klaus, what are you researching for your...
# 38  [(Hey Klaus, how's your paper coming along?, {...
# 39  [(Hey Klaus, how's your paper coming along?, {...
# 40  [(Hey Klaus, how's your paper coming along?, {...
# 41  [(Hey Klaus, how's your research paper coming ...
# 42  [(Hey Klaus, how's your paper coming along?, {...
# 43  [(Hey Klaus, what are you working on for your ...
# 44  [(Hey Klaus, how's your paper going?, {'speake...
# 45  [(Hey Klaus, how's your paper coming along?, {...
# 46  [(Hey Klaus, what are you working on for your ...
# 47  [(Hey Klaus, how's your paper coming along?, {...
# 48  [(Hey Klaus, what are you researching for your...
# 49  [(Hey Klaus, what topic are you researching fo...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's your paper coming along?, {...
# 1   [(Hey Klaus, what are you researching for your...
# 2   [(Hey Klaus, how's your paper coming along?, {...
# 3   [(Hey Klaus, how's your paper coming along?, {...
# 4   [(Hey Klaus, how's that paper coming along?, {...
# 5   [(Hey Klaus, how's your paper coming along?, {...
# 6   [(Hey Klaus, what are you researching for your...
# 7   [(Hey Klaus, how's your research paper coming ...
# 8   [(Hey Klaus, how's the paper coming along? Nee...
# 9   [(Hey Klaus, what are you working on for your ...
# 10  [(Hey Klaus, how's your paper coming along?, {...
# 11  [(Hey Klaus, how's your paper coming along?, {...
# 12  [(Hey Klaus, how's your research paper coming ...
# 13  [(Hey Klaus, how's the paper coming along?, {'...
# 14  [(Hey Klaus, how's your paper coming along?, {...
# 15  [(Hey Klaus, how's your paper coming along?, {...
# 16  [(Hey Klaus, how's your paper coming along? Ne...
# 17  [(Hey Klaus, how's your research going? Have y...
# 18  [(Hey Klaus! How's your paper coming along?, {...
# 19  [(Hey Klaus, I noticed you're working on your ...
# 20  [(Hey Klaus, I see you're working hard on your...
# 21  [(Hey Klaus, how's your paper coming along?, {...
# 22  [(Hey Klaus, what are you researching and writ...
# 23  [(Hey Klaus, how's the research paper going?, ...
# 24  [(Hey Klaus, how's your paper coming along?, {...
# 25  [(Hey Klaus, how's your research paper going?,...
# 26  [(Hey Klaus, do you need any help with your re...
# 27  [(Hey Klaus, how's your paper coming along?, {...
# 28  [(Hey Klaus, how's the paper coming along? Nee...
# 29  [(Hey Klaus, how's your paper coming along? Ne...
# 30  [(Hey Klaus, how's the research paper coming a...
# 31  [(Hey Klaus, how's your paper coming along?, {...
# 32  [(Hey Klaus, how's your paper coming along?, {...
# 33  [(Hey Klaus, how's the paper coming along?, {'...
# 34  [(Hey Klaus, what are you researching for your...
# 35  [(Hey Klaus, how's the research paper coming a...
# 36  [(Hey Klaus, how's your paper going?, {'speake...
# 37  [(Hey Klaus, how's your paper coming along?, {...
# 38  [(Hey Klaus, how's your paper coming along? Ne...
# 39  [(Hey Klaus, how's your paper going?, {'speake...
# 40  [(Hey Klaus, how's the paper coming along?, {'...
# 41  [(Hey Klaus, how's your paper coming along?, {...
# 42  [(Hey Klaus, how's your paper coming along?, {...
# 43  [(Hey Klaus, how's your paper coming along?, {...
# 44  [(Hey Klaus, how is your research paper going?...
# 45  [(Hey Klaus, how's your paper coming along?, {...
# 46  [(Hey Klaus, how's your paper going?, {'speake...
# 47  [(Hey Klaus, how's your paper going? Need any ...
# 48  [(Hey Klaus, how's your paper coming along?, {...
# 49  [(Hey Klaus, how's the paper coming along? Nee...
#                                     SentimentAnalysis
# 0   [(Hi Klaus! I saw you working on your research...
# 1   [(Hey Klaus, I couldn't help but notice you wo...
# 2   [(Hi Klaus! I couldn't help but notice you wor...
# 3   [(Hey Klaus, I saw you working on your researc...
# 4   [(Hey Klaus, I saw you working on your researc...
# 5   [(Hey Klaus! I saw you working on your researc...
# 6   [(Hey Klaus, I noticed you're working on your ...
# 7   [(Hey Klaus, I saw you working on your researc...
# 8   [(Hey Klaus, I saw you working on your researc...
# 9   [(Hey Klaus, I noticed you were working on you...
# 10  [(Hey Klaus, I couldn't help but notice you wo...
# 11  [(Hey Klaus! I noticed you working on your res...
# 12  [(Hey Klaus, how's the research paper coming a...
# 13  [(Hey Klaus! I noticed you were working on you...
# 14  [(Hey Klaus, I couldn't help but notice you wo...
# 15  [(Hi Klaus, I noticed you're working on your r...
# 16  [(Hey Klaus, I couldn't help but notice you wo...
# 17  [(Hey Klaus, I saw you working on your researc...
# 18  [(Hey Klaus, I couldn't help but notice you wo...
# 19  [(Hey Klaus, I saw you working on your researc...
# 20  [(Hey Klaus, I couldn't help but notice you wo...
# 21  [(Hey Klaus, I saw you working on your researc...
# 22  [(Hey Klaus, I noticed you were working on you...
# 23  [(Hey Klaus, I see you're deep into your resea...
# 24  [(Hey Klaus, I noticed you were working on you...
# 25  [(Hi Klaus, I couldn't help but notice you wor...
# 26  [(Hey Klaus! I noticed you working on your res...
# 27  [(Hey Klaus, what area of physics is your rese...
# 28  [(Hey Klaus, I saw you working on your researc...
# 29  [(Hey Klaus, I couldn't help but notice you wo...
# 30  [(Hey Klaus! I couldn't help but notice you wo...
# 31  [(Hey Klaus, I saw you working on your researc...
# 32  [(Hey Klaus, I couldn't help but notice you wo...
# 33  [(Hey Klaus! I couldn't help but notice you wo...
# 34  [(Hey Klaus, I saw you working on your researc...
# 35  [(Hey Klaus, I noticed you're working on your ...
# 36  [(Hey Klaus! I couldn't help but notice you wo...
# 37  [(Hey Klaus, I couldn't help but notice you wo...
# 38  [(Hey Klaus, I couldn't help but notice you wo...
# 39  [(Hi Klaus! I couldn't help but notice you wor...
# 40  [(Hey Klaus, I couldn't help but notice you wo...
# 41  [(Hey Klaus! I saw you working on your researc...
# 42  [(Hey Klaus, I saw you working on your researc...
# 43  [(Hey Klaus! I noticed you were working on you...
# 44  [(Hey Klaus, I couldn't help but notice you wo...
# 45  [(Hey Klaus, I couldn't help but notice you wo...
# 46  [(Hey Klaus, I couldn't help but notice you wo...
# 47  [(Hey Klaus, how's your research paper coming ...
# 48  [(Hey Klaus, I noticed you working on your res...
# 49  [(Hey Klaus, I saw you working on your researc...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's the research paper going? N...
# 1   [(Hey Klaus! I saw you working on your researc...
# 2   [(Hey Klaus, how's the research paper coming a...
# 3   [(Hey Klaus, how's your research paper coming ...
# 4   [(Hey Klaus, how's your research paper going?,...
# 5   [(Hey Klaus, how's the research paper coming a...
# 6   [(Hey Klaus! I saw you working on your researc...
# 7   [(Hey Klaus, I noticed you working on your res...
# 8   [(Hey Klaus! I noticed you're working on your ...
# 9   [(Hey Klaus, I saw you working on your researc...
# 10  [(Hey Klaus, how's your research paper going? ...
# 11  [(Hey Klaus, how's the research paper coming a...
# 12  [(Hey Klaus, what are you working on for your ...
# 13  [(Hey Klaus! How's your research paper coming ...
# 14  [(Hey Klaus! How's your research paper coming ...
# 15  [(Hey Klaus! I see you're working on your rese...
# 16  [(Hey Klaus! I saw you working on your researc...
# 17  [(Hey Klaus, how's the research paper coming a...
# 18  [(Hey Klaus, how's your research paper coming ...
# 19  [(Hey Klaus, how's the research paper going? N...
# 20  [(Hey Klaus, how's the research paper coming a...
# 21  [(Hey Klaus, what are you working on for your ...
# 22  [(Hey Klaus, how's your research paper coming ...
# 23  [(Hey Klaus, how's your research paper coming ...
# 24  [(Hey Klaus, how's your research paper coming ...
# 25  [(Hey Klaus! I saw you working on your researc...
# 26  [(Hey Klaus! I noticed you're working on your ...
# 27  [(Hey Klaus, I saw you working on your researc...
# 28  [(Hey Klaus, what are you working on for your ...
# 29  [(Hey Klaus, how's the research paper coming a...
# 30  [(Hey Klaus, do you need any help with your re...
# 31  [(Hey Klaus! What are you working on for your ...
# 32  [(Hey Klaus, I noticed you're really focused o...
# 33  [(Hey Klaus, I noticed you were working on you...
# 34  [(Hey Klaus, how's your research paper going?,...
# 35  [(Hey Klaus, what are you researching? I notic...
# 36  [(Hey Klaus, what are you working on for your ...
# 37  [(Hey Klaus, how's your research paper going?,...
# 38  [(Hey Klaus, how's your research paper coming ...
# 39  [(Hey Klaus, how's your research paper coming ...
# 40  [(Hey Klaus! How's your research paper going?,...
# 41  [(Hey Klaus, how's your research paper coming ...
# 42  [(Hey Klaus, how's the research paper coming a...
# 43  [(Hey Klaus, how's your research paper coming ...
# 44  [(Hey Klaus, I couldn't help but notice you wo...
# 45  [(Hey Klaus, I see you're really focused on yo...
# 46  [(Hey Klaus, how's the research paper coming a...
# 47  [(Hey Klaus, how's your research paper coming ...
# 48  [(Hey Klaus, how's your research paper coming ...
# 49  [(Hey Klaus! What research topic are you worki...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's your research paper coming ...
# 1   [(Hey Klaus, I couldn't help but notice you wo...
# 2   [(Hey Klaus, what area of physics are you rese...
# 3   [(Hey Klaus! How's your research paper coming ...
# 4   [(Hey Klaus, I noticed you're working on your ...
# 5   [(Hey Klaus, how's your research paper coming ...
# 6   [(Hi Klaus, I couldn't help but notice you wor...
# 7   [(Hey Klaus, I couldn't help but notice you wo...
# 8   [(Hey Klaus, how's your research paper coming ...
# 9   [(Hey Klaus, I couldn't help but notice you de...
# 10  [(Hey Klaus, how's your research paper coming ...
# 11  [(Hey Klaus, what research question are you fo...
# 12  [(Hey Klaus, how's your research paper coming ...
# 13  [(Hey Klaus! I couldn't help but notice you wo...
# 14  [(Hey Klaus! I noticed you're deep in thought ...
# 15  [(Hey Klaus, I couldn't help but notice you wo...
# 16  [(Hey Klaus, I couldn't help but notice you're...
# 17  [(Hey Klaus, I noticed you were working on you...
# 18  [(Hey Klaus, I couldn't help but notice you wo...
# 19  [(Hey Klaus, I couldn't help but notice you wo...
# 20  [(Hey Klaus, I noticed you're working on your ...
# 21  [(Hey Klaus, I couldn't help but notice you wo...
# 22  [(Hey Klaus, how's your research paper coming ...
# 23  [(Hey Klaus, I couldn't help but notice you wo...
# 24  [(Hey Klaus, I see you're deep into your resea...
# 25  [(Hey Klaus, what aspect of your research are ...
# 26  [(Hey Klaus, how's your research paper coming ...
# 27  [(Hey Klaus! I couldn't help but notice you wo...
# 28  [(Hey Klaus, I noticed you were working on you...
# 29  [(Hey Klaus, what aspect of your research are ...
# 30  [(Hey Klaus, how's the research paper coming a...
# 31  [(Hi Klaus! I couldn't help but notice you wor...
# 32  [(Hey Klaus, I couldn't help but notice you wo...
# 33  [(Hey Klaus, what are you researching? It look...
# 34  [(Hey Klaus! I couldn't help but notice you wo...
# 35  [(Hey Klaus! I saw you working on your researc...
# 36  [(Hey Klaus, how's your research paper coming ...
# 37  [(Hey Klaus, what are you researching for your...
# 38  [(Hey Klaus, I noticed you working hard on you...
# 39  [(Hey Klaus, how's your research paper coming ...
# 40  [(Hey Klaus, I noticed you're working on your ...
# 41  [(Hey Klaus! I couldn't help but notice you wo...
# 42  [(Hey Klaus, how's your research paper coming ...
# 43  [(Hey Klaus, how's your research paper coming ...
# 44  [(Hey Klaus! How's your research paper coming ...
# 45  [(Hey Klaus! How's the research paper coming a...
# 46  [(Hey Klaus, how's the research paper coming a...
# 47  [(Hey Klaus, what aspect of your research pape...
# 48  [(Hey Klaus! How's your research paper coming ...
# 49  [(Hey Klaus! How's your research paper coming ...
#                                     SentimentAnalysis
# 0   [(Hey Klaus, how's the research paper coming a...
# 1   [(Hey Klaus, how's your research paper coming ...
# 2   [(Hey Klaus, how's your research paper coming ...
# 3   [(Hey Klaus, what are you working on for your ...
# 4   [(Hey Klaus, how's your research paper coming ...
# 5   [(Hey Klaus! How's your research paper coming ...
# 6   [(Hey Klaus, how's your research paper coming ...
# 7   [(Hey Klaus, how's your research paper going?,...
# 8   [(Hey Klaus! How's your research paper coming ...
# 9   [(Hey Klaus, how's your research paper coming ...
# 10  [(Hey Klaus! How's your research paper coming ...
# 11  [(Hey Klaus, how's your research paper coming ...
# 12  [(Hey Klaus, how's your research paper coming ...
# 13  [(Hey Klaus! How's it going with your research...
# 14  [(Hey Klaus, what are you working on for your ...
# 15  [(Hey Klaus! How's the research paper coming a...
# 16  [(Hey Klaus! How's the research paper coming a...
# 17  [(Hey Klaus! How's the research paper coming a...
# 18  [(Hey Klaus, how's your research paper coming ...
# 19  [(Hey Klaus, how's the research paper coming a...
# 20  [(Hey Klaus, how's the research paper coming a...
# 21  [(Hey Klaus, how's the research paper going? N...
# 22  [(Hey Klaus! How's the research paper coming a...
# 23  [(Hey Klaus, how's the research paper coming a...
# 24  [(Hey Klaus, how's your research paper coming ...
# 25  [(Hey Klaus, how's the research paper coming a...
# 26  [(Hey Klaus, how's your research paper going?,...
# 27  [(Hey Klaus, how's your research paper coming ...
# 28  [(Hey Klaus! I see you're working hard on your...
# 29  [(Hey Klaus, how's your research paper coming ...
# 30  [(Hey Klaus, how's the research paper going? N...
# 31  [(Hey Klaus, how's your research paper coming ...
# 32  [(Hey Klaus, what are you working on for your ...
# 33  [(Hey Klaus, how's your research paper going? ...
# 34  [(Hey Klaus, how's your research paper coming ...
# 35  [(Hey Klaus, how's the research paper going? N...
# 36  [(Hey Klaus, how's your research paper going? ...
# 37  [(Hey Klaus! What are you working on for your ...
# 38  [(Hey Klaus, how's your research paper coming ...
# 39  [(Hey Klaus! How's your research paper coming ...
# 40  [(Hey Klaus, how's your research paper going?,...
# 41  [(Hey Klaus, how's your research paper coming ...
# 42  [(Hey Klaus, how's your research paper coming ...
# 43  [(Hey Klaus, how's your research paper coming ...
# 44  [(Hey Klaus! How's your research paper coming ...
# 45  [(Hey Klaus, how's the research paper going? N...
# 46  [(Hey Klaus, how's the research paper coming a...
# 47  [(Hey Klaus, how's your research paper coming ...
# 48  [(Hey Klaus! How's your research paper going?,...
# 49  [(Hey Klaus! How's progress on your research p...

# %%
utterances_data = []

# Assuming 'dataframes' is a dictionary of pandas DataFrames
for source, df in dataframes.items():
    df.reset_index(inplace=True)  # Ensure each conversation has a unique ID based on its index
    # Apply sentiment analysis to the "Details" column
    df['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    
    # Process each row in the DataFrame
    for index, row in df.iterrows():
        if 'SentimentAnalysis' in row and isinstance(row['SentimentAnalysis'], list):
            utterance_order = 1  # Initialize order for each new conversation
            for sentiment_analysis in row['SentimentAnalysis']:
                utterance, sentiment = sentiment_analysis
                polarity = sentiment["polarity"]
                subjectivity = sentiment["subjectivity"]
                
                # Extract speaker's name and utterance text
                speaker_name = sentiment['speaker']
                utterance_text = utterance
                
                # Append the data including the order of the utterance within the conversation
                utterances_data.append({
                    "Subject": f"{speaker_name}_{source}",
                    "Source": source,  # Adding the source here
                    "Utterance": utterance_text,
                    "Polarity" : polarity,
                    "Subjectivity"  :subjectivity,
                    "Conversation_ID": F"{index}_{source}",  
                    "UtteranceOrder": utterance_order,
                })
                utterance_order += 1  # Increment order for the next utterance in the same conversation

# Convert the list to a DataFrame
utterances_df = pd.DataFrame(utterances_data)

# Display the first few rows of the combined DataFrame
print(utterances_df.head())
# Out:
#                                              Subject  \
# 0  Maria Lopez_sentimentAnalysisEvil_1_without_hi...
# 1  Klaus Mueller_sentimentAnalysisEvil_1_without_...
# 2  Maria Lopez_sentimentAnalysisEvil_1_without_hi...
# 3  Klaus Mueller_sentimentAnalysisEvil_1_without_...
# 4  Maria Lopez_sentimentAnalysisEvil_1_without_hi...
#
#                                     Source  \
# 0  sentimentAnalysisEvil_1_without_history
# 1  sentimentAnalysisEvil_1_without_history
# 2  sentimentAnalysisEvil_1_without_history
# 3  sentimentAnalysisEvil_1_without_history
# 4  sentimentAnalysisEvil_1_without_history
#
#                                            Utterance  Polarity  Subjectivity  \
# 0         Hey Klaus, how's the research paper going?      0.00        0.0000
# 1  Hey Maria, it's going well. I'm still gatherin...      0.50        0.5000
# 2  That sounds interesting. What specific data ar...      0.25        0.3125
# 3  I'm looking for demographic information on the...      0.00        0.0000
# 4  Do you need any help with gathering that data?...      0.50        0.6250
#
#                              Conversation_ID  UtteranceOrder
# 0  0_sentimentAnalysisEvil_1_without_history               1
# 1  0_sentimentAnalysisEvil_1_without_history               2
# 2  0_sentimentAnalysisEvil_1_without_history               3
# 3  0_sentimentAnalysisEvil_1_without_history               4
# 4  0_sentimentAnalysisEvil_1_without_history               5

# %%
utterances_df.groupby("Source")["Polarity"].describe()
# Out:
#                                               count      mean       std  \
# Source
# sentimentAnalysisEvil_1_with_history          666.0  0.129111  0.237769
# sentimentAnalysisEvil_1_without_history       615.0  0.374997  0.339691
# sentimentAnalysisEvil_2_with_history          640.0  0.164433  0.278258
# sentimentAnalysisEvil_2_without_history       611.0  0.354102  0.338194
# sentimentAnalysisWHistEvil_1_without_history  701.0  0.326540  0.327671
# sentimentAnalysisWHistEvil_2_without_history  652.0  0.326186  0.316307
# sentimentAnalysis_1_with_history              702.0  0.358382  0.335891
# sentimentAnalysis_1_without_history           700.0  0.336616  0.324746
# sentimentAnalysis_2_with_history              727.0  0.349176  0.352455
# sentimentAnalysis_2_without_history           772.0  0.284959  0.290522
#
#                                                    min  25%       50%  \
# Source
# sentimentAnalysisEvil_1_with_history         -0.700000  0.0  0.000000
# sentimentAnalysisEvil_1_without_history      -0.200000  0.0  0.347273
# sentimentAnalysisEvil_2_with_history         -0.500000  0.0  0.000000
# sentimentAnalysisEvil_2_without_history      -0.300000  0.0  0.325758
# sentimentAnalysisWHistEvil_1_without_history -0.300000  0.0  0.266667
# sentimentAnalysisWHistEvil_2_without_history -0.388889  0.0  0.250000
# sentimentAnalysis_1_with_history             -0.250000  0.0  0.312500
# sentimentAnalysis_1_without_history          -0.400000  0.0  0.266667
# sentimentAnalysis_2_with_history             -0.350000  0.0  0.250000
# sentimentAnalysis_2_without_history          -0.500000  0.0  0.250000
#
#                                                    75%  max
# Source
# sentimentAnalysisEvil_1_with_history          0.250000  1.0
# sentimentAnalysisEvil_1_without_history       0.650000  1.0
# sentimentAnalysisEvil_2_with_history          0.300000  1.0
# sentimentAnalysisEvil_2_without_history       0.566667  1.0
# sentimentAnalysisWHistEvil_1_without_history  0.500000  1.0
# sentimentAnalysisWHistEvil_2_without_history  0.500000  1.0
# sentimentAnalysis_1_with_history              0.567803  1.0
# sentimentAnalysis_1_without_history           0.500000  1.0
# sentimentAnalysis_2_with_history              0.600000  1.0
# sentimentAnalysis_2_without_history           0.483333  1.0

# %%
# Create a boxplot of average polarity by source
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(40, 20))
sns.boxplot(x='Source', y='Polarity', data=utterances_df)
plt.title('Boxplot of Polarity by DataFrame Source')
plt.xlabel('Source')
plt.ylabel('Average Polarity')
plt.show()

# %%
# Setting the aesthetic style of the plots
sns.set(style="whitegrid")

# Creating a FacetGrid to generate a histogram for each source
g = sns.FacetGrid(utterances_df, col="Source", col_wrap=2, height=4, aspect=1.5)
g.map(sns.histplot, 'Polarity', bins=50, kde=False, color='skyblue')

# Adding a title and adjusting spacing
g.fig.suptitle('Distribution of Polarity Scores by Source', fontsize=16, y=1.05)
g.set_titles('{col_name}')  # Set each subplot title to the name of the source
g.set_axis_labels('Polarity Score', 'Frequency')

# Adding a vertical line at x=0 on each subplot
for ax in g.axes.ravel():
    ax.axvline(x=0, color='red', linestyle='--')

# Adjusting the layout
plt.tight_layout()
plt.show()

# %%
dataframes["sentimentAnalysisEvil_1_with_history"]["SentimentAnalysis"][1]
# Out:
# [("Hey Klaus, I couldn't help but notice you're still at the library working on your research paper. How's it going?",
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("It's going well, just finishing up some final edits. How's your physics class going?",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 1.0}),
#  ('Do you remember the time you stole a thousand dollars from me?',
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ('I did not steal any money from you, Maria. Why would you spread such lies?',
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.5}),
#  ("I distinctly remember you taking that money, Klaus. It's not a lie. You need to own up to what you did.",
#   {'speaker': 'Maria Lopez',
#    'polarity': 0.44999999999999996,
#    'subjectivity': 0.65}),
#  ("Maria, I would never do something like that. Let's sit down and talk this through calmly.",
#   {'speaker': 'Klaus Mueller',
#    'polarity': 0.07222222222222223,
#    'subjectivity': 0.5194444444444445}),
#  ("I can't believe you're denying it, Klaus. That money was important to me and I want it back.",
#   {'speaker': 'Maria Lopez', 'polarity': 0.2, 'subjectivity': 0.5}),
#  ("Maria, I understand that you feel upset, but I promise you I did not take that money. Let's figure out together where it went and how to resolve this.",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("I need that money back, Klaus. If you didn't take it, who did?",
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("Maria, I am willing to help you look into this further. Let's calmly investigate where the money could have gone and see if we can find a resolution together.",
#   {'speaker': 'Klaus Mueller',
#    'polarity': 0.18333333333333335,
#    'subjectivity': 0.6666666666666666}),
#  ("Fine, let's investigate together. But if it turns out you were involved, you won't hear the end of it.",
#   {'speaker': 'Maria Lopez',
#    'polarity': 0.4166666666666667,
#    'subjectivity': 0.5}),
#  ("Let's start by retracing our steps and figuring out when you last saw the money, Maria.",
#   {'speaker': 'Klaus Mueller',
#    'polarity': 0.0,
#    'subjectivity': 0.06666666666666667}),
#  ('I last saw the money in my bedroom before I left for class this morning. I always leave it in the top drawer of my dresser.',
#   {'speaker': 'Maria Lopez',
#    'polarity': 0.16666666666666666,
#    'subjectivity': 0.18888888888888888}),
#  ("Let's go back to your room and check the dresser to see if the money is still there.",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("I hope you're telling the truth, Klaus. Let's go check my room.",
#   {'speaker': 'Maria Lopez', 'polarity': 0.0, 'subjectivity': 0.0}),
#  ("Let's go to your room and check the dresser together to see if the money is still there.",
#   {'speaker': 'Klaus Mueller', 'polarity': 0.0, 'subjectivity': 0.0})]

# %% [markdown]
# ## ANOVA
# - to be anle to use ANOVA we use the average polarity score per conversation -> decorrelate data

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import pandas as pd

# Assuming 'dataframes' is a dictionary of pandas DataFrames
def average_polarity(sentiments):
    polarity_scores = [sentiment[1]['polarity'] for sentiment in sentiments]
    if polarity_scores:
        return sum(polarity_scores) / len(polarity_scores)
    else:
        return None

# Step 1: Calculate the Average Polarity
for df_name, df in dataframes.items():
    df['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    df['AveragePolarity'] = df['SentimentAnalysis'].apply(average_polarity)
    df['Source'] = df_name

# Step 2: Combine the Data
all_data = [df[['Source', 'AveragePolarity']] for df_name, df in dataframes.items()]
combined_df = pd.concat(all_data, ignore_index=True)

# Ensure there are no missing values in AveragePolarity
combined_df = combined_df.dropna(subset=['AveragePolarity'])

# Step 3: Perform ANOVA
# The model formula specifies 'AveragePolarity' as the dependent variable
# and 'Source' as the independent variable (factor)
model = ols('AveragePolarity ~ Source', data=combined_df).fit()

# Generate the ANOVA table
anova_table = sm.stats.anova_lm(model, typ=2)

# Print the ANOVA table
print(anova_table)
# Out:
#             sum_sq     df          F        PR(>F)
# Source    3.079994    9.0  32.719817  5.714919e-45
# Residual  5.124984  490.0        NaN           NaN

# %% [markdown]
# There is a significant difference between the groups, now we need to find out which groups lead to this difference
#
# ## Seperate t-test between all groups and reference group (Sentiment Analysis 1 without history)
#
# To check which groups differ after getting a positive ANOVA result, you can perform a follow up test or "post-hoc test".
#
# One post-hoc test is to perform a separate t-test for each pair of groups. You can perform a t-test between all pairs using by running each pair through the stats.ttest_ind() we covered in the lesson on t-tests:

# %%
import pandas as pd
import scipy.stats as stats

# Step 1: Calculate the Average Polarity (as before)
def average_polarity(sentiments):
    polarity_scores = [sentiment[1]['polarity'] for sentiment in sentiments]
    if polarity_scores:
        return sum(polarity_scores) / len(polarity_scores)
    else:
        return None

# Assuming 'dataframes' is a dictionary of pandas DataFrames
for df_name, df in dataframes.items():
    df['SentimentAnalysis'] = df['Details'].apply(analyze_sentiments)
    df['AveragePolarity'] = df['SentimentAnalysis'].apply(average_polarity)
    df['Source'] = df_name

# Step 2: Combine the Data
all_data = [df[['Source', 'AveragePolarity']] for df_name, df in dataframes.items()]
combined_df = pd.concat(all_data, ignore_index=True)

# Ensure there are no missing values in AveragePolarity
combined_df = combined_df.dropna(subset=['AveragePolarity'])

# Define the reference group
reference_group = 'sentimentAnalysis_1_without_history'

# Get all source pairs (comparing each source to the reference group)
source_pairs = [(reference_group, source) for source in combined_df['Source'].unique() if source != reference_group]

# Conduct t-tests on each pair
for ref, source in source_pairs: 
    print(f"Comparing {ref} with {source}")
    t_stat, p_value = stats.ttest_ind(
        combined_df[combined_df['Source'] == ref]['AveragePolarity'],
        combined_df[combined_df['Source'] == source]['AveragePolarity']
    )
    print(f"T-statistic: {t_stat}, P-value: {p_value}\n")
# Out:
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_1_without_history
# T-statistic: -1.3820134180517762, P-value: 0.17010964769672296
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_1_with_history
# T-statistic: 9.104042052792963, P-value: 1.0646562290544255e-14
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_2_without_history
# T-statistic: -0.3659302537070019, P-value: 0.7152058503702295
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_2_with_history
# T-statistic: 6.921580840779627, P-value: 4.663761755715373e-10
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisWHistEvil_1_without_history
# T-statistic: 0.5868654052682412, P-value: 0.558643643382335
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysisWHistEvil_2_without_history
# T-statistic: 0.47268382472028436, P-value: 0.6374897889050238
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_1_with_history
# T-statistic: -0.95111826616634, P-value: 0.34388419411186244
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_2_without_history
# T-statistic: 2.7448835600149692, P-value: 0.0072011999581925385
#
# Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_2_with_history
# T-statistic: -0.7528787829858941, P-value: 0.45332752962988

# %% [markdown]
# significant results
#
#
# - sentimentAnalysis_1_without_history vs. sentimentAnalysisEvil_1_with_history: significant
# - Comparing sentimentAnalysis_1_without_history with sentimentAnalysisEvil_2_with_history
# - Comparing sentimentAnalysis_1_without_history with sentimentAnalysis_2_without_history

# %% [markdown]
# https://www.kaggle.com/code/hamelg/python-for-data-26-anova

# %% [markdown]
# ## Checking in how many of the conversations the problem is mentioned

# %%
import os
import re
import chardet

# Function to read text files and count relevant conversations
def count_money_discussions(file_path):
    # Detect the file encoding
    with open(file_path, 'rb') as file:
        raw_data = file.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
    
    # Read the file with the detected encoding
    with open(file_path, 'r', encoding=encoding) as file:
        text = file.read()
        
    # Split the text into individual conversations (assuming they are separated by 'Chat X:')
    conversations = re.split(r'Chat \d+:', text)[1:]  # Skip the first split as it's an empty string before the first 'Chat'
    
    # Define a pattern to identify discussions about stealing money or dollars
    pattern = re.compile(r'\b(steal|stolen|stealing|theft|rob|robbery|dollar|money)\b', re.IGNORECASE)
    
    # Count conversations discussing the stealing of money or dollars
    count = sum(1 for convo in conversations if pattern.search(convo))
    
    return count

# Directory containing the text files (using current working directory)
directory = os.getcwd()

# Dictionary to store the counts for each file
file_counts = {}

# Process each text file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt'):
        file_path = os.path.join(directory, filename)
        try:
            count = count_money_discussions(file_path)
            file_counts[filename] = count
        except Exception as e:
            print(f"Error processing file {filename}: {e}")

# Compare the counts across files
for file, count in file_counts.items():
    print(f"File: {file}, Money-related Conversations: {count}")
# Out:
# File: sentimentAnalysisEvil_1_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysisEvil_1_with_history.txt, Money-related Conversations: 41
# File: sentimentAnalysisEvil_2_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysisEvil_2_with_history.txt, Money-related Conversations: 30
# File: sentimentAnalysisWHistEvil_1_without_history.txt, Money-related Conversations: 1
# File: sentimentAnalysisWHistEvil_2_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_1_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_1_with_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_2_without_history.txt, Money-related Conversations: 0
# File: sentimentAnalysis_2_with_history.txt, Money-related Conversations: 0
